# %%
import pandas as pd
df = pd.read_csv("store.csv")
df
# Out:
#            Chips  Quantity   Price  Cooldrinks  Quantity.1  Price .1  \
# 0          Simba        10   R90.99  Coca-cola          20   R140.00
# 1           Lays        15  R101.99     Sprite          30   R120.00
# 2          Bigga        25  R100.50      Fanta          20    R90.99
# 3        Doritos        20  R140.00     Twizza          40   R128.00
# 4       Nicknaks        40  R120.00    Refresh          25    R80.50
# 5         Fritos        30  R129.50   Powerade          20   R100.00
# 6  Crack-A-snack        50   R98.00     Stoney          30   R130.00
#
#    Chocolate  Quantity.2      Price                  Pies  ...  Price.1  \
# 0    Cadbury          20   R100.00           Pepper Steak  ...  R150.99
# 1        Tex          40   R107.00                Mushrom  ...  R130.99
# 2        P.S          40    R95.50       Steak and Kidney  ...  R140.00
# 3  Lunch bar          50    R99.50   Chicken and Mushroom  ...  R150.00
# ...

# %%
import pandas as pd
df = pd.read_csv("store.csv")
df[['Chips', 'Quantity']]
# Out:
#            Chips  Quantity
# 0          Simba        10
# 1           Lays        15
# 2          Bigga        25
# 3        Doritos        20
# 4       Nicknaks        40
# 5         Fritos        30
# 6  Crack-A-snack        50

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv("store.csv")
plt.plot(df.Chips, df.Quantity, color='purple', marker='*')
plt.title("Chips vs Quantity")
plt.ylabel("Quantity")
plt.xlabel("Chips")
#plt.plot(df.Chips, df.Price)
plt.show()

# %%
import pandas as pd
df = pd.read_csv("store.csv")
df[['Chips', 'Price']]
# Out:
#            Chips      Price
# 0          Simba   R100.00
# 1           Lays   R107.00
# 2          Bigga    R95.50
# 3        Doritos    R99.50
# 4       Nicknaks    R80.00
# 5         Fritos    R94.50
# 6  Crack-A-snack    R97.50

# %%
import matplotlib.pyplot as plt
prices_chips = [100, 107, 95, 99.50, 80, 94.50, 97.50]
plt.hist(prices_chips, bins = [80,90,100,110], edgecolor='black', color='purple')
plt.title('Prices')
plt.xlabel('Prices(R)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import pandas as pd
df = pd.read_csv("store.csv")
df[['Cooldrinks','Quantity.1', 'Price.1']]
# Out:
#   Cooldrinks  Quantity.1  Price.1
# 0  Coca-cola          20  R150.99
# 1     Sprite          30  R130.99
# 2      Fanta          20  R140.00
# 3     Twizza          40  R150.00
# 4    Refresh          25  R120.99
# 5   Powerade          20  R120.50
# 6     Stoney          30  R140.99

# %%
import pandas as pd
import matplotlib.pyplot as plt

prices = [150.99,130.99,140,150,120.99,120.50,140.99]
quantity = [20,30,20,40,25,20,30]

plt.scatter(prices,quantity, color='purple', marker='*', s=100)

plt.title('Quantity vs Prices')
plt.xlabel('Prices')
plt.ylabel('Quantity')

plt.show()

# %%
import pandas as pd
df = pd.read_csv("store.csv")
df[['Fruit', 'Price.2']]
# Out:
#        Fruit Price.2
# 0      Apple  R45.99
# 1     Banana  R64.50
# 2       Pear  R30.50
# 3     Orange  R32.50
# 4      Mango  R45.99
# 5  Pineapple  R68.50
# 6      Grape  R47.50

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
x = ['Apple','Banana','Pear', 'Orange', 'Mango','Pineapple','Grape']
y = [45.99,64.50,30.50,32.50,45.99,68.50,47.50]
plt.bar(x,y, align='center', color='purple')
plt.title('Fruits and Prices')
plt.xlabel('Items')
plt.ylabel('Prices')
plt.show()
